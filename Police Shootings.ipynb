# %% [markdown]
# # Introduction
#
# ### In the United States, use of deadly force by police has been a high-profile and contentious issue. Police killings are one of the leading causes of death for young men in the United States

# %%
## import the packages
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
sns.set()

# %%
## load in the data
data = pd.read_csv("datasets_723010_1257097_fatal-police-shootings-data.csv")

# %%
## check the data
data.head()
# Out:
#    id                name        date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  2015-01-02              shot         gun  53.0
# 1   4    Lewis Lee Lembke  2015-01-02              shot         gun  47.0
# 2   5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  2015-01-04              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  2015-01-04              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# ...

# %%
## check the info of the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5416 entries, 0 to 5415
# Data columns (total 14 columns):
# id                         5416 non-null int64
# name                       5416 non-null object
# date                       5416 non-null object
# manner_of_death            5416 non-null object
# armed                      5189 non-null object
# age                        5181 non-null float64
# gender                     5414 non-null object
# race                       4895 non-null object
# city                       5416 non-null object
# state                      5416 non-null object
# signs_of_mental_illness    5416 non-null bool
# threat_level               5416 non-null object
# flee                       5167 non-null object
# body_camera                5416 non-null bool
# dtypes: bool(2), float64(1), int64(1), object(10)
# memory usage: 518.5+ KB

# %%
## check for missing values
data.isnull().sum()
# Out:
# id                           0
# name                         0
# date                         0
# manner_of_death              0
# armed                      227
# age                        235
# gender                       2
# race                       521
# city                         0
# state                        0
# signs_of_mental_illness      0
# threat_level                 0
# flee                       249
# body_camera                  0
# dtype: int64

# %%
## check the description of the data
data.describe()
# Out:
#                 id          age
# count  5416.000000  5181.000000
# mean   3010.398264    37.117931
# std    1695.786456    13.116135
# min       3.000000     6.000000
# 25%    1545.750000    27.000000
# 50%    3009.500000    35.000000
# 75%    4486.250000    46.000000
# max    5927.000000    91.000000

# %%
## drop the missing value
data.dropna(inplace=True)

# %%
## check the data again
data.head()
# Out:
#    id                name        date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  2015-01-02              shot         gun  53.0
# 1   4    Lewis Lee Lembke  2015-01-02              shot         gun  47.0
# 2   5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  2015-01-04              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  2015-01-04              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# ...

# %%
## check for missing values
data.isnull().sum()
# Out:
# id                         0
# name                       0
# date                       0
# manner_of_death            0
# armed                      0
# age                        0
# gender                     0
# race                       0
# city                       0
# state                      0
# signs_of_mental_illness    0
# threat_level               0
# flee                       0
# body_camera                0
# dtype: int64

# %%
## check the shape of the data
data.shape
# Out:
# (4399, 14)

# %%
## check the columns
data.columns
# Out:
# Index(['id', 'name', 'date', 'manner_of_death', 'armed', 'age', 'gender',
#        'race', 'city', 'state', 'signs_of_mental_illness', 'threat_level',
#        'flee', 'body_camera'],
#       dtype='object')

# %%
## check the relationship
sns.heatmap(data.corr())

# %%
sns.distplot(data["age"])

# %%
sns.countplot(x="race", hue="gender", data=data)

# %%
sns.stripplot(x="race", y="age", data=data)

# %%
data["manner_of_death"].unique()
# Out:
# array(['shot', 'shot and Tasered'], dtype=object)

# %%
sns.stripplot(x="race", y="age", hue="manner_of_death", data=data)

# %%
data["manner_of_death"].value_counts()
# Out:
# shot                4169
# shot and Tasered     230
# Name: manner_of_death, dtype: int64

# %%
sns.countplot(data["manner_of_death"])

# %%
data["armed"].unique()
# Out:
# array(['gun', 'unarmed', 'toy weapon', 'nail gun', 'knife', 'shovel',
#        'hammer', 'hatchet', 'undetermined', 'sword', 'machete',
#        'box cutter', 'metal object', 'screwdriver', 'lawn mower blade',
#        'flagpole', 'guns and explosives', 'cordless drill', 'metal pole',
#        'Taser', 'metal pipe', 'metal hand tool', 'blunt object',
#        'metal stick', 'sharp object', 'meat cleaver', 'carjack', 'chain',
#        "contractor's level", 'unknown weapon', 'stapler', 'crossbow',
#        'bean-bag gun', 'baseball bat and fireplace poker',
#        'straight edge razor', 'gun and knife', 'ax', 'brick',
#        'baseball bat', 'hand torch', 'chain saw', 'garden tool',
#        'scissors', 'pole', 'pick-axe', 'flashlight', 'vehicle', 'spear',
#        'chair', 'pitchfork', 'hatchet and gun', 'rock', 'piece of wood',
#        'bayonet', 'glass shard', 'motorcycle', 'pepper spray',
#        'metal rake', 'baton', 'crowbar', 'oar', 'machete and gun',
# ...

# %%
data["armed"].value_counts()
# Out:
# gun                    2596
# knife                   660
# unarmed                 336
# toy weapon              165
# vehicle                 117
#                        ...
# vehicle and machete       1
# machete and gun           1
# chain saw                 1
# car, knife and mace       1
# glass shard               1
# Name: armed, Length: 90, dtype: int64

# %%
data["threat_level"].value_counts()
# Out:
# attack          2911
# other           1322
# undetermined     166
# Name: threat_level, dtype: int64

# %%
sns.countplot(hue=data['threat_level'],x=data['manner_of_death'])

# %%
sns.countplot(x="threat_level", hue="gender", data=data)

# %%
sns.violinplot(x='signs_of_mental_illness',y='age',data=data)

# %%
sns.violinplot(x='flee',y='age',data=data,hue='gender',split=True)

# %%
sns.countplot(x=data['signs_of_mental_illness'])

# %%
sns.countplot(x='signs_of_mental_illness', hue="gender", data=data)

# %%
sns.countplot(data["body_camera"])

# %%
data['state'].value_counts()
# Out:
# CA    623
# TX    383
# FL    294
# AZ    200
# CO    153
# GA    146
# NC    137
# OK    137
# OH    133
# TN    114
# WA    113
# MO    112
# IL     88
# IN     87
# LA     87
# PA     86
# NY     85
# VA     85
# AL     85
# WI     82
# NM     81
# NV     76
# KY     73
# SC     71
# OR     67
# MI     67
# MD     66
# AR     64
# MN     56
# UT     54
# MS     52
# NJ     52
# KS     46
# WV     37
# ID     34
# AK     33
# MA     30
# IA     29
# HI     23
# MT     22
# NE     22
# CT     17
# ME     17
# DC     13
# SD     13
# WY     13
# NH     12
# ND     10
# DE      9
# VT      8
# RI      2
# Name: state, dtype: int64

# %%
plt.figure(figsize=(20,20))
sns.barplot(x=data['state'].value_counts().index,y=data['state'].value_counts())

# %% [markdown]
# # Arigato :)
